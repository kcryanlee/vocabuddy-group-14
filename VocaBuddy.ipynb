# %% [markdown]
# <a href="https://colab.research.google.com/github/kcryanlee/vocabuddy-group-14/blob/main/VocaBuddy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
vocab = {
    "apple": "蘋果",
    "book": "書",
    "computer": "電腦"
}

print("VocaBuddy 單字庫")
print("----------------")

for word, meaning in vocab.items():
    print(word, ":", meaning)
# Out:
# VocaBuddy 單字庫
# ----------------
# apple : 蘋果
# book : 書
# computer : 電腦
